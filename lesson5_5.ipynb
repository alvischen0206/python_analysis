# %%
import pandas as pd
import requests

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 取得 YouBike 資料
URL = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    # 取得資料
    response = requests.get(URL)
    if response.status_code == 200:
        # 將 JSON 資料轉換成 DataFrame
        df = pd.DataFrame(response.json())
        
        # 重新命名欄位
        columns_mapping = {
            'sna': '站點名稱',
            'sarea': '區域',
            'ar': '地址',
            'tot': '總車位',
            'sbi': '可借車數',
            'bemp': '可還車數'
        }
        
        # 選擇要顯示的欄位並重新命名
        df_display = df[['sna', 'sarea', 'ar', 'tot', 'sbi', 'bemp']].rename(columns=columns_mapping)
        
        # 計算各區域的統計資訊
        area_stats = df_display.groupby('區域').agg({
            '站點名稱': 'count',
            '總車位': 'sum',
            '可借車數': ['sum', 'mean'],
            '可還車數': ['sum', 'mean']
        }).round(2)
        
        # 重新命名統計欄位
        area_stats.columns = ['站點數', '總車位數', '可借車總數', '平均可借車數', '可還車總數', '平均可還車數']
        
        print("YouBike 各區域統計資訊：")
        print("-" * 80)
        print(area_stats)
        
        # 顯示可借車數最少的5個站點
        print("\n可借車數量最少的5個站點：")
        print("-" * 80)
        print(df_display.nsmallest(5, '可借車數')[['站點名稱', '區域', '可借車數', '總車位']])
        
        # 儲存分析結果
        df_display.to_csv('youbike_current.csv', encoding='utf-8-sig', index=False)
        area_stats.to_csv('youbike_stats.csv', encoding='utf-8-sig')
        
        print("\n資料已儲存至 youbike_current.csv 和 youbike_stats.csv")
        
except Exception as e:
    print(f"發生錯誤：{str(e)}")
# Out:
# 發生錯誤："['tot', 'sbi', 'bemp'] not in index"

# %%
import pandas as pd
import requests

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 取得 YouBike 資料
URL = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    # 取得資料
    response = requests.get(URL)
    if response.status_code == 200:
        # 將 JSON 資料轉換成 DataFrame
        df = pd.DataFrame(response.json())
        
        # 先檢查實際的欄位名稱
        print("可用的欄位名稱：")
        print(df.columns.tolist())
        
        # 重新命名欄位（根據實際的欄位名稱）
        columns_mapping = {
            'sna': '站點名稱',
            'sarea': '區域',
            'ar': '地址',
            'tot': '總車位',
            'sbi': '可借車數',
            'bemp': '可還車數',
            'act': '站點狀態'
        }
        
        # 選擇要顯示的欄位並重新命名
        df_display = df[columns_mapping.keys()].rename(columns=columns_mapping)
        
        print("\nYouBike 即時資料：")
        print("-" * 50)
        print(df_display.head())
        
        # 計算各區域的統計資訊
        area_stats = df_display.groupby('區域').agg({
            '站點名稱': 'count',
            '總車位': 'sum',
            '可借車數': ['sum', 'mean'],
            '可還車數': ['sum', 'mean']
        }).round(2)
        
        # 重新命名統計欄位
        area_stats.columns = ['站點數', '總車位數', '可借車總數', '平均可借車數', '可還車總數', '平均可還車數']
        
        print("\nYouBike 各區域統計資訊：")
        print("-" * 80)
        print(area_stats)
        
except Exception as e:
    print(f"發生錯誤：{str(e)}")
    print("\n詳細錯誤資訊：")
    import traceback
    print(traceback.format_exc())
# Out:
# 可用的欄位名稱：
# ['sno', 'sna', 'sarea', 'mday', 'ar', 'sareaen', 'snaen', 'aren', 'act', 'srcUpdateTime', 'updateTime', 'infoTime', 'infoDate', 'total', 'available_rent_bikes', 'latitude', 'longitude', 'available_return_bikes']
# 發生錯誤："['tot', 'sbi', 'bemp'] not in index"
#
# 詳細錯誤資訊：
# Traceback (most recent call last):
#   File "C:\Users\bigpa\AppData\Local\Temp\ipykernel_19508\3366242061.py", line 36, in <module>
#     df_display = df[columns_mapping.keys()].rename(columns=columns_mapping)
#                  ~~^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\frame.py", line 4108, in __getitem__
#     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\indexes\base.py", line 6200, in _get_indexer_strict
#     self._raise_if_missing(keyarr, indexer, axis_name)
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\indexes\base.py", line 6252, in _raise_if_missing
#     raise KeyError(f"{not_found} not in index")
# KeyError: "['tot', 'sbi', 'bemp'] not in index"

# %%
import pandas as pd
import requests

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# 取得 YouBike 資料
URL = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    # 取得資料
    response = requests.get(URL)
    if response.status_code == 200:
        # 將 JSON 資料轉換成 DataFrame
        df = pd.DataFrame(response.json())
        
        # 重新命名欄位（根據實際的欄位名稱）
        columns_mapping = {
            'sna': '站點名稱',
            'sarea': '區域',
            'ar': '地址',
            'total': '總車位',
            'available_rent_bikes': '可借車數',
            'available_return_bikes': '可還車數',
            'act': '站點狀態'
        }
        
        # 選擇要顯示的欄位並重新命名
        df_display = df[columns_mapping.keys()].rename(columns=columns_mapping)
        
        print("\nYouBike 即時資料：")
        print("-" * 50)
        print(df_display)
        
        # 計算各區域的統計資訊
        area_stats = df_display.groupby('區域').agg({
            '站點名稱': 'count',
            '總車位': 'sum',
            '可借車數': ['sum', 'mean'],
            '可還車數': ['sum', 'mean']
        }).round(2)
        
        # 重新命名統計欄位
        area_stats.columns = ['站點數', '總車位數', '可借車總數', '平均可借車數', '可還車總數', '平均可還車數']
        
        print("\nYouBike 各區域統計資訊：")
        print("-" * 80)
        print(area_stats)
        
        # 儲存分析結果
        df_display.to_csv('youbike_current.csv', encoding='utf-8-sig', index=False)
        area_stats.to_csv('youbike_stats.csv', encoding='utf-8-sig')
        
except Exception as e:
    print(f"發生錯誤：{str(e)}")
# Out:
# YouBike 即時資料：
# --------------------------------------------------
#                                           站點名稱          區域  \
# 0                        YouBike2.0_捷運科技大樓站        大安區
# 1                   YouBike2.0_復興南路二段273號前        大安區
# 2                    YouBike2.0_國北教大實小東側門        大安區
# 3                          YouBike2.0_和平公園東側        大安區
# 4                    YouBike2.0_辛亥復興路口西北側        大安區
# 5                   YouBike2.0_復興南路二段280號前        大安區
# 6                   YouBike2.0_復興南路二段340巷口        大安區
# 7                    YouBike2.0_新生南路三段52號前        大安區
# 8                    YouBike2.0_新生南路三段66號前        大安區
# 9                    YouBike2.0_新生南路三段82號前        大安區
# 10                     YouBike2.0_辛亥路一段30號前        大安區
# 11                   YouBike2.0_和平復興路口西北側        大安區
# 12                  YouBike2.0_羅斯福路三段311號前        大安區
# 13                   YouBike2.0_大安運動中心停車場        大安區
# 14                  YouBike2.0_羅斯福路三段245號前        大安區
# 15                             YouBike2.0_溫州公園        大安區
# 16                         YouBike2.0_和平臥龍街口        大安區
# 17                           YouBike2.0_溫州停車場        大安區
# 18                         YouBike2.0_銘傳國小側門        大安區
# 19                  YouBike2.0_捷運公館站(2號出口)        大安區
# 20                     YouBike2.0_第二學生活動中心        大安區
# 21                     YouBike2.0_臺灣科技大學正門        大安區
# 22                     YouBike2.0_臺灣科技大學側門        大安區
# 23                             YouBike2.0_公館公園        大安區
# 24                     YouBike2.0_臺灣科技大學後門        大安區
# 25               YouBike2.0_臺大醫學院附設癌醫中心        大安區
# 26                         YouBike2.0_臺大環研大樓        大安區
# 27                   YouBike2.0_臺大永齡生醫工程館        大安區
# 28                         YouBike2.0_臺大男七舍前        大安區
# 29                         YouBike2.0_臺大男一舍前        大安區
# 30                         YouBike2.0_臺大男六舍前        大安區
# 31                       YouBike2.0_臺大動物醫院前        大安區
# 32                   YouBike2.0_臺大土木研究大樓前        大安區
# 33                         YouBike2.0_臺大萬才館前        大安區
# 34                   YouBike2.0_臺大國青大樓宿舍前        大安區
# 35                   YouBike2.0_臺大社科院圖書館前        大安區
# 36               YouBike2.0_臺大法人語言訓練中心前        大安區
# 37               YouBike2.0_臺大綜合體育館停車場前        大安區
# 38                   YouBike2.0_辛亥新生路口東南側        大安區
# 39                     YouBike2.0_基隆長興路口東側        大安區
# 40                     YouBike2.0_國北教大側門南側        大安區
# 41                       YouBike2.0_和平實小東北側        大安區
# 42                   YouBike2.0_大安區健康服務中心        大安區
# 43                         YouBike2.0_辛亥泰順街口        大安區
# 44                             YouBike2.0_芳和國中        大安區
# 45                         YouBike2.0_臥龍樂業街口        大安區
# 46                             YouBike2.0_臥龍公園        大安區
# 47                             YouBike2.0_嘉興公園        大安區
# 48                  YouBike2.0_捷運麟光站(2號出口)        大安區
# 49                         YouBike2.0_捷運六張犁站        大安區
# 50                             YouBike2.0_喬治工商        大安區
# 51                             YouBike2.0_法治公園        大安區
# 52              YouBike2.0_捷運臺電大樓站(2號出口)        大安區
# 53                         YouBike2.0_和平金山路口        大安區
# 54                         YouBike2.0_和平龍泉街口        大安區
# 55                         YouBike2.0_和平泰順街口        大安區
# 56                 YouBike2.0_臺灣師範大學(圖書館)        大安區
# 57                  YouBike2.0_捷運古亭站(6號出口)        大安區
# 58                  YouBike2.0_捷運古亭站(5號出口)        大安區
# 59                 YouBike2.0_臺北市立圖書館(總館)        大安區
# 60                   YouBike2.0_新生和平路口東北側        大安區
# 61                   YouBike2.0_建國和平路口西北側        大安區
# 62                             YouBike2.0_金華公園        大安區
# 63                  YouBike2.0_捷運東門站(3號出口)        大安區
# 64                             YouBike2.0_金甌女中        大安區
# 65                             YouBike2.0_金杭公園        大安區
# 66                         YouBike2.0_愛國金山路口        大安區
# 67              YouBike2.0_敦化南路二段293巷口南側        大安區
# 68                         YouBike2.0_敦化基隆路口        大安區
# 69                    YouBike2.0_安和路二段181巷口        大安區
# 70            YouBike2.0_臨江街夜市(通化街101巷口)        大安區
# 71                   YouBike2.0_臨江街夜市(基隆路)        大安區
# 72                 YouBike2.0_台北科技大學億光大樓        大安區
# 73                  YouBike2.0_新生南路一段119巷口        大安區
# 74                     YouBike2.0_幸安國小(仁愛路)        大安區
# 75                             YouBike2.0_民榮公園        大安區
# 76                   YouBike2.0_復興南路1段340巷口        大安區
# 77                         YouBike2.0_建國濟南路口        大安區
# 78              YouBike2.0_捷運忠孝復興站(2號出口)        大安區
# 79                  YouBike2.0_捷運大安站(4號出口)        大安區
# 80                  YouBike2.0_捷運大安站(2號出口)        大安區
# 81               YouBike2.0_信義大安路口(信維大樓)        大安區
# 82                             YouBike2.0_龍門廣場        大安區
# 83                         YouBike2.0_仁愛安和路口        大安區
# 84                         YouBike2.0_信義敦化路口        大安區
# 85                             YouBike2.0_仁愛國中        大安區
# 86              YouBike2.0_捷運信義安和站(2號出口)        大安區
# 87                             YouBike2.0_八德市場        大安區
# 88                             YouBike2.0_昌隆公園        大安區
# 89          YouBike2.0_捷運大安森林公園站(2號出口)        大安區
# 90                         YouBike2.0_信義延吉街口        大安區
# 91              YouBike2.0_光信公園(光復南路456巷)        大安區
# 92        YouBike2.0_僑安地下停車場(2號出口)東南側        大安區
# 93                  YouBike2.0_建國南路一段279巷口        大安區
# 94              YouBike2.0_捷運忠孝新生站(6號出口)        大安區
# 95              YouBike2.0_捷運忠孝新生站(4號出口)        大安區
# 96                             YouBike2.0_大安高工        大安區
# 97              YouBike2.0_捷運忠孝新生站(3號出口)        大安區
# 98                             YouBike2.0_瑠公公園        大安區
# 99                         YouBike2.0_敦化市民路口        大安區
# 100         YouBike2.0_捷運大安森林公園站(5號出口)        大安區
# 101                        YouBike2.0_信義建國路口        大安區
# 102                            YouBike2.0_東豐公園        大安區
# 103                YouBike2.0_德安公園(四維路66巷)        大安區
# 104             YouBike2.0_捷運忠孝復興站(5號出口)        大安區
# 105             YouBike2.0_捷運忠孝敦化站(2號出口)        大安區
# 106             YouBike2.0_捷運忠孝敦化站(7號出口)        大安區
# 107     YouBike2.0_忠孝東路四段223巷口(市民大道側)        大安區
# 108                         YouBike2.0_瑞安街208巷        大安區
# 109                        YouBike2.0_樂利路21巷口        大安區
# 110        YouBike2.0_捷運科技大樓站(台北教育大學)        大安區
# 111           YouBike2.0_捷運國父紀念館站(2號出口)        大安區
# 112                            YouBike2.0_仁愛醫院        大安區
# 113             YouBike2.0_捷運信義安和站(4號出口)        大安區
# 114                            YouBike2.0_成功國宅        大安區
# 115                        YouBike2.0_仁愛延吉街口        大安區
# 116             YouBike2.0_捷運信義安和站(1號出口)        大安區
# 117                 YouBike2.0_敦化南路二段103巷口        大安區
# 118                 YouBike2.0_復興南路二段128巷口        大安區
# 119                    YouBike2.0_和平東建國南路口        大安區
# 120                            YouBike2.0_芳蘭山莊        大安區
# 121                 YouBike2.0_復興南路一段126巷口        大安區
# 122                 YouBike2.0_捷運東門站(5號出口)        大安區
# 123                    YouBike2.0_仁愛路四段48巷口        大安區
# 124                 YouBike2.0_捷運公館站(3號出口)        大安區
# 125            YouBike2.0_臺北科技大學(電機工程系)        大安區
# 126                  YouBike2.0_新生南路三段94巷口        大安區
# 127                  YouBike2.0_辛亥新生路口西北側        大安區
# 128                 YouBike2.0_捷運大安站(6號出口)        大安區
# 129                       YouBike2.0_臥龍街195巷口        大安區
# 130                   YouBike2.0_辛亥路三段157巷口        大安區
# 131                        YouBike2.0_臥龍基隆路口        大安區
# 132                            YouBike2.0_敦親公園        大安區
# 133                        YouBike2.0_大安運動中心        大安區
# 134                        YouBike2.0_和平敦化路口        大安區
# 135                        YouBike2.0_基隆長興路口        大安區
# 136                   YouBike2.0_仁愛路四段122巷口        大安區
# 137                        YouBike2.0_市民敦化路口        大安區
# 138                  YouBike2.0_忠孝東路四段49巷口        大安區
# 139                YouBike2.0_市民復興路口(東南側)        大安區
# 140                  YouBike2.0_和平新生路口西南側        大安區
# 141                            YouBike2.0_全安公園        大安區
# 142                   YouBike2.0_信義路三段134巷口        大安區
# 143                YouBike2.0_仁愛敦南圓環(東南側)        大安區
# 144                    YouBike2.0_臺北遠企購物中心        大安區
# 145            YouBike2.0_外交部外交及國際事務學院        大安區
# 146                       YouBike2.0_四維路170巷口        大安區
# 147                 YouBike2.0_捷運大安站(3號出口)        大安區
# 148           YouBike2.0_捷運臺電大樓站(2號出口)_1        大安區
# 149                     YouBike2.0_信義路四段199巷        大安區
# 150                        YouBike2.0_臺大資訊大樓        大安區
# 151                    YouBike2.0_敦化南路二段81巷        大安區
# 152                    YouBike2.0_原臺北刑務所官舍        大安區
# 153           YouBike2.0_捷運國父紀念館站(1號出口)        大安區
# 154                            YouBike2.0_懷生國中        大安區
# 155                YouBike2.0_仁愛敦南圓環(西北側)        大安區
# 156                            YouBike2.0_立人國小        大安區
# 157                  YouBike2.0_和平東路二段18巷口        大安區
# 158                 YouBike2.0_捷運大安站(5號出口)        大安區
# 159                            YouBike2.0_臨江公園        大安區
# 160             YouBike2.0_羅斯福路四段113巷19弄口        大安區
# 161                 YouBike2.0_忠孝東路四段248巷口        大安區
# 162                YouBike2.0_仁愛延吉路口(西北側)        大安區
# 163                       YouBike2.0_樂利路101巷口        大安區
# 164                      YouBike2.0_羅斯福浦城街口        大安區
# 165                 YouBike2.0_敦化南路一段295巷口        大安區
# 166                    YouBike2.0_通安區民活動中心        大安區
# 167              YouBike2.0_復興忠孝東路口(東南側)        大安區
# 168                YouBike2.0_仁愛大安路口(東北側)        大安區
# 169                YouBike2.0_臺灣師範大學(浦城街)        大安區
# 170                    YouBike2.0_安和路二段69巷口        大安區
# 171                            YouBike2.0_大安國小        大安區
# 172                 YouBike2.0_捷運古亭站(3號出口)        大安區
# 173             YouBike2.0_捷運忠孝復興站(3號出口)        大安區
# 174                    YouBike2.0_和平東路二段90巷        大安區
# 175                     YouBike2.0_光復南路420巷口        大安區
# 176                        YouBike2.0_富陽臥龍街口        大安區
# 177                        YouBike2.0_仁愛復興路口        大安區
# 178                  YouBike2.0_仁愛敦南圓環(東側)        大安區
# 179                            YouBike2.0_古風公園        大安區
# 180                    YouBike2.0_和平東路二段76巷        大安區
# 181                YouBike2.0_敦化信義路口(東南側)        大安區
# 182                 YouBike2.0_和平東路三段308巷口        大安區
# 183                YouBike2.0_忠孝建國路口(東南側)        大安區
# 184                          YouBike2.0_浦城街26巷        大安區
# 185                        YouBike2.0_青峰活動中心        大安區
# 186                 YouBike2.0_忠孝東路三段216巷口        大安區
# 187             YouBike2.0_捷運忠孝復興站(4號出口)        大安區
# 188                        YouBike2.0_和平溫州街口        大安區
# 189              YouBike2.0_國立臺北教育大學創意館        大安區
# 190             YouBike2.0_捷運忠孝復興站(1號出口)        大安區
# 191                        YouBike2.0_政大公企中心        大安區
# 192                    YouBike2.0_大安路二段90巷口        大安區
# 193                    YouBike2.0_師大附中運動中心        大安區
# 194                            YouBike2.0_延平國宅        大同區
# 195              YouBike2.0_臺北市立圖書館大同分館        大同區
# 196                              YouBike2.0_合昌宮        大同區
# 197                        YouBike2.0_民族延平路口        大同區
# 198                        YouBike2.0_重慶酒泉街口        大同區
# 199                            YouBike2.0_樹德公園        大同區
# 200                          YouBike2.0_陳天來故居        大同區
# 201                            YouBike2.0_臺北孔廟        大同區
# 202                 YouBike2.0_捷運圓山站(1號出口)        大同區
# 203                        YouBike2.0_酒泉延平路口        大同區
# 204                            YouBike2.0_重慶國中        大同區
# 205                 YouBike2.0_重慶北路三段383巷口        大同區
# 206                    YouBike2.0_台北數位產業園區        大同區
# 207                YouBike2.0_民權延平路口(西北側)        大同區
# 208                        YouBike2.0_民權迪化街口        大同區
# 209                          YouBike2.0_大稻埕公園        大同區
# 210                        YouBike2.0_大龍老人住宅        大同區
# 211                      YouBike2.0_大龍峒社會住宅        大同區
# 212               YouBike2.0_捷運大橋頭站(2號出口)        大同區
# 213                YouBike2.0_捷運大橋頭站(1A出口)        大同區
# 214             YouBike2.0_捷運民權西路站(2號出口)        大同區
# 215                 YouBike2.0_捷運雙連站(2號出口)        大同區
# 216                 YouBike2.0_捷運北門站(3號出口)        大同區
# 217                            YouBike2.0_朝陽公園        大同區
# 218                            YouBike2.0_永樂市場        大同區
# 219                            YouBike2.0_大龍公園        大同區
# 220                        YouBike2.0_重慶涼州街口        大同區
# 221                        YouBike2.0_圓山線形公園        大同區
# 222                              YouBike2.0_圓環站        大同區
# 223                        YouBike2.0_重慶民族路口        大同區
# 224                     YouBike2.0_承德路三段8巷口        大同區
# 225                            YouBike2.0_太原廣場        大同區
# 226                            YouBike2.0_國順公園        大同區
# 227                    YouBike2.0_聯合醫院中興院區        大同區
# 228                      YouBike2.0_蔣渭水紀念公園        大同區
# 229                    YouBike2.0_迪化休閒運動公園        大同區
# 230                        YouBike2.0_大同運動中心        大同區
# 231          YouBike2.0_重慶保安街口(家樂福重慶店)        大同區
# 232                          YouBike2.0_大稻埕碼頭        大同區
# 233                        YouBike2.0_歸綏戲曲公園        大同區
# 234                  YouBike2.0_民權國中(民權西路)        大同區
# 235                        YouBike2.0_承德民權路口        大同區
# 236                        YouBike2.0_南京太原路口        大同區
# 237                      YouBike2.0_承德民生西路口        大同區
# 238                        YouBike2.0_太原五原路口        大同區
# 239                  YouBike2.0_臺北轉運站(華陰街)        大同區
# 240             YouBike2.0_捷運民權西路站(3號出口)        大同區
# 241                 YouBike2.0_捷運中山站(5號出口)        大同區
# 242                        YouBike2.0_重慶長安路口        大同區
# 243                        YouBike2.0_承德昌吉街口        大同區
# 244                        YouBike2.0_大同16號廣場        大同區
# 245                 YouBike2.0_捷運圓山站(2號出口)        大同區
# 246                          YouBike2.0_樹德公園_1        大同區
# 247            YouBike2.0_承德鄭州路口(市民高架下)        大同區
# 248                            YouBike2.0_成淵高中        大同區
# 249                            YouBike2.0_雙蓮國小        大同區
# 250                        YouBike2.0_寧夏涼州街口        大同區
# 251                        YouBike2.0_延平涼州街口        大同區
# 252                        YouBike2.0_大同行政中心        大同區
# 253                            YouBike2.0_大龍市場        大同區
# 254              YouBike2.0_南京西寧北路口(西北側)        大同區
# 255                    YouBike2.0_哈密街23巷19弄口        大同區
# 256                     YouBike2.0_民權西路160巷口        大同區
# 257                 YouBike2.0_重慶北路三段205巷口        大同區
# 258                    YouBike2.0_承德路二段91巷口        大同區
# 259                        YouBike2.0_酒泉庫倫街口        大同區
# 260                      YouBike2.0_民族西大龍街口        大同區
# 261                          YouBike2.0_劍潭抽水站        士林區
# 262                    YouBike2.0_通河東街大南路口        士林區
# 263                        YouBike2.0_福港街停車場        士林區
# 264                            YouBike2.0_百齡國小        士林區
# 265                       YouBike2.0_雨聲街165巷口        士林區
# 266                            YouBike2.0_天和公園        士林區
# 267                        YouBike2.0_中山天母路口        士林區
# 268                        YouBike2.0_天母運動公園        士林區
# 269              YouBike2.0_臺北市立大學(天母校區)        士林區
# 270                      YouBike2.0_忠誠路二段53巷        士林區
# 271                          YouBike2.0_天母棒球場        士林區
# 272                      YouBike2.0_天母北天玉街口        士林區
# 273                            YouBike2.0_蘭興公園        士林區
# 274                            YouBike2.0_明勝公園        士林區
# 275                YouBike2.0_劍潭海外青年活動中心        士林區
# 276                   YouBike2.0_忠誠路一段173巷口        士林區
# 277                            YouBike2.0_雨農國小        士林區
# 278                            YouBike2.0_忠誠公園        士林區
# 279                          YouBike2.0_芝山抽水站        士林區
# 280                   YouBike2.0_至誠路一段305巷口        士林區
# 281                            YouBike2.0_華齡公園        士林區
# 282                    YouBike2.0_前港公園(福德宮)        士林區
# 283                       YouBike2.0_華齡街185巷口        士林區
# 284                    YouBike2.0_前港公園(前港街)        士林區
# 285                            YouBike2.0_百齡高中        士林區
# 286                 YouBike2.0_捷運芝山站(2號出口)        士林區
# 287                        YouBike2.0_臺灣戲曲中心        士林區
# 288                 YouBike2.0_捷運劍潭站(2號出口)        士林區
# 289                        YouBike2.0_劍潭基河路口        士林區
# 290                            YouBike2.0_志成公園        士林區
# 291                            YouBike2.0_福林國小        士林區
# 292                        YouBike2.0_中山中正路口        士林區
# 293                        YouBike2.0_士林運動中心        士林區
# 294                            YouBike2.0_陽明高中        士林區
# 295                          YouBike2.0_兒童新樂園        士林區
# 296                      YouBike2.0_臺北市立天文館        士林區
# 297                            YouBike2.0_華聲公園        士林區
# 298                            YouBike2.0_福林公園        士林區
# 299                 YouBike2.0_捷運士林站(2號出口)        士林區
# 300                            YouBike2.0_銘傳大學        士林區
# 301                            YouBike2.0_士林高商        士林區
# 302                            YouBike2.0_蘭雅公園        士林區
# 303                    YouBike2.0_聯合醫院陽明院區        士林區
# 304                 YouBike2.0_捷運芝山站(1號出口)        士林區
# 305                            YouBike2.0_至誠公園        士林區
# 306                  YouBike2.0_原住民文化主題公園        士林區
# 307                   YouBike2.0_通河東街2段10巷口        士林區
# 308                            YouBike2.0_梅林新村        士林區
# 309                      YouBike2.0_延平北中正路口        士林區
# 310                 YouBike2.0_重慶北路四段190巷口        士林區
# 311                      YouBike2.0_重慶北葫東街口        士林區
# 312                            YouBike2.0_葫蘆國小        士林區
# 313                         YouBike2.0_士林3號廣場        士林區
# 314                            YouBike2.0_社正公園        士林區
# 315                            YouBike2.0_社子國小        士林區
# 316                       YouBike2.0_社中街384巷口        士林區
# 317                     YouBike2.0_忠誠路一段138號        士林區
# 318                            YouBike2.0_社子公園        士林區
# 319                      YouBike2.0_國立故宮博物院        士林區
# 320                            YouBike2.0_泰北高中        士林區
# 321                            YouBike2.0_後港公園        士林區
# 322                   YouBike2.0_重慶北路四段117號        士林區
# 323                      YouBike2.0_社子島島頭公園        士林區
# 324                 YouBike2.0_延平北路八段133巷口        士林區
# 325                              YouBike2.0_坤天亭        士林區
# 326                  YouBike2.0_社子島濕地解說小築        士林區
# 327                            YouBike2.0_福安國中        士林區
# 328                        YouBike2.0_福安消防分隊        士林區
# 329                            YouBike2.0_聖山綠地        士林區
# 330                            YouBike2.0_芝山國小        士林區
# 331                          YouBike2.0_士林新天地        士林區
# 332                            YouBike2.0_蘭雅國小        士林區
# 333                        YouBike2.0_中正基河路口        士林區
# 334                    YouBike2.0_福林公園(中正路)        士林區
# 335                        YouBike2.0_至善臨溪路口        士林區
# 336                YouBike2.0_市立圖書館葫蘆堵分館        士林區
# 337                       YouBike2.0_東山路110巷口        士林區
# 338                        YouBike2.0_永平社會住宅        士林區
# 339                              YouBike2.0_雨農橋        士林區
# 340         YouBike2.0_通河街76巷/承德路四段10巷口        士林區
# 341                          YouBike2.0_芝山聖佑宮        士林區
# 342                        YouBike2.0_至誠雨聲街口        士林區
# 343                  YouBike2.0_捷運線型公園(後街)        士林區
# 344                            YouBike2.0_天母公園        士林區
# 345                        YouBike2.0_基河文林路口        士林區
# 346                        YouBike2.0_文林福華路口        士林區
# 347              YouBike2.0_劍潭海外青年活動中心_1        士林區
# 348                          YouBike2.0_社子國小_1        士林區
# 349                 YouBike2.0_捷運劍潭站(1號出口)        士林區
# 350                        YouBike2.0_德行東山路口        士林區
# 351                    YouBike2.0_重慶北通河西街口        士林區
# 352         YouBike2.0_葫蘆國小(延平北路五段285巷)        士林區
# 353                            YouBike2.0_社子市場        士林區
# 354                  YouBike2.0_士林區農會社子分部        士林區
# 355                        YouBike2.0_承德劍潭路口        士林區
# 356                       YouBike2.0_文林路101巷口        士林區
# 357             YouBike2.0_延平北路五段257巷15弄口        士林區
# 358              YouBike2.0_延平北路五段257巷4弄口        士林區
# 359                            YouBike2.0_啟明學校        士林區
# 360                        YouBike2.0_中山福國路口        士林區
# 361                            YouBike2.0_德行公園        士林區
# 362                        YouBike2.0_承德後港街口        士林區
# 363                 YouBike2.0_中山北路五段698巷口        士林區
# 364                 YouBike2.0_捷運士林站(1號出口)        士林區
# 365               YouBike2.0_捷運芝山站(2號出口)_1        士林區
# 366       YouBike2.0_銘傳大學(中山北路五段280巷口)        士林區
# 367                        YouBike2.0_海光公園南側        士林區
# 368                        YouBike2.0_士商路40巷口        士林區
# 369                            YouBike2.0_劍潭郵局        士林區
# 370                        YouBike2.0_士東路91巷口        士林區
# 371                            YouBike2.0_美崙公園        士林區
# 372       YouBike2.0_臺北市立大學(忠誠路二段207巷)        士林區
# 373       YouBike2.0_天母東路8巷/忠誠路二段154巷口        士林區
# 374                    YouBike2.0_美崙公園(東北側)        士林區
# 375                        YouBike2.0_福安河濱公園        士林區
# 376                  YouBike2.0_忠誠忠義街口(北側)        士林區
# 377                  YouBike2.0_忠誠忠義街口(南側)        士林區
# 378                            YouBike2.0_士林國小        士林區
# 379                        YouBike2.0_雙溪濕地公園        士林區
# 380      YouBike2.0_劍潭海外青年活動中心(志清大樓)        士林區
# 381                        YouBike2.0_天和一號公園        士林區
# 382                   YouBike2.0_忠誠路二段178巷口        士林區
# 383                        YouBike2.0_克強磺溪街口        士林區
# 384                      YouBike2.0_蘭雅公園(西側)        士林區
# 385                   YouBike2.0_福林路100巷77弄口        士林區
# 386                   YouBike2.0_福林路100巷11弄口        士林區
# 387     YouBike2.0_重慶北路四段190巷口(通河西街側)        士林區
# 388                    YouBike2.0_承德區民活動中心        士林區
# 389                       YouBike2.0_福林路255巷口        士林區
# 390                 YouBike2.0_中山北路五段378巷口        士林區
# 391                    YouBike2.0_台北花木批發市場        文山區
# 392                 YouBike2.0_捷運萬隆站(4號出口)        文山區
# 393                 YouBike2.0_捷運萬隆站(1號出口)        文山區
# 394                        YouBike2.0_萬和二號公園        文山區
# 395                 YouBike2.0_捷運萬隆站(2號出口)        文山區
# 396                            YouBike2.0_景仁公園        文山區
# 397                 YouBike2.0_捷運景美站(2號出口)        文山區
# 398                      YouBike2.0_羅斯福景隆街口        文山區
# 399           YouBike2.0_景福街/羅斯福路6段142巷口        文山區
# 400                            YouBike2.0_興旺公園        文山區
# 401                            YouBike2.0_興福國中        文山區
# 402                      YouBike2.0_興隆路2段203巷        文山區
# 403                        YouBike2.0_景美運動公園        文山區
# 404                            YouBike2.0_景美醫院        文山區
# 405                    YouBike2.0_師範大學公館校區        文山區
# 406                       YouBike2.0_景華街128巷口        文山區
# 407                YouBike2.0_仙跡岩登山口(景興路)        文山區
# 408                        YouBike2.0_國立政治大學        文山區
# 409                        YouBike2.0_捷運動物園站        文山區
# 410                          YouBike2.0_捷運木柵站        文山區
# 411                      YouBike2.0_捷運萬芳社區站        文山區
# 412                        YouBike2.0_文山運動中心        文山區
# 413                          YouBike2.0_捷運辛亥站        文山區
# 414                            YouBike2.0_興豐公園        文山區
# 415                        YouBike2.0_木柵光輝路口        文山區
# 416                              YouBike2.0_考試院        文山區
# 417                        YouBike2.0_和興路26巷口        文山區
# 418                            YouBike2.0_世新大學        文山區
# 419                              YouBike2.0_一壽橋        文山區
# 420                    YouBike2.0_臺北市立景美女中        文山區
# 421                 YouBike2.0_永安藝文館-表演36房        文山區
# 422                    YouBike2.0_忠順區民活動中心        文山區
# 423                            YouBike2.0_景文中學        文山區
# 424                        YouBike2.0_老泉街籃球場        文山區
# 425                        YouBike2.0_文山行政中心        文山區
# 426                            YouBike2.0_木柵公園        文山區
# 427                    YouBike2.0_興隆公共住宅D2區        文山區
# 428                     YouBike2.0_木新路3段95巷口        文山區
# 429                          YouBike2.0_樟腳里公園        文山區
# 430                            YouBike2.0_實踐國中        文山區
# 431                        YouBike2.0_指南路3段2巷        文山區
# 432                            YouBike2.0_萊茵公園        文山區
# 433                        YouBike2.0_木柵社會住宅        文山區
# 434                   YouBike2.0_秀明路一段185巷口        文山區
# 435                   YouBike2.0_秀明路一段129巷口        文山區
# 436                      YouBike2.0_恆光橋(老泉街)        文山區
# 437                         YouBike2.0_萬有3號公園        文山區
# 438     YouBike2.0_捷運萬芳醫院站(興隆路三段115巷)        文山區
# 439                          YouBike2.0_興得閱覽室        文山區
# 440                        YouBike2.0_辛亥生態公園        文山區
# 441                        YouBike2.0_博嘉運動公園        文山區
# 442                            YouBike2.0_仙岩公園        文山區
# 443                          YouBike2.0_政大一街口        文山區
# 444                    YouBike2.0_文山第二行政中心        文山區
# 445                      YouBike2.0_移民署訓練中心        文山區
# 446                        YouBike2.0_海巡署(南側)        文山區
# 447                      YouBike2.0_明道國小東南側        文山區
# 448                            YouBike2.0_木南公園        文山區
# 449         YouBike2.0_實踐國中(木新路三段310巷口)        文山區
# 450                  YouBike2.0_師範大學公館校區_1        文山區
# 451               YouBike2.0_捷運動物園站(2號出口)        文山區
# 452                        YouBike2.0_政大水岸電梯        文山區
# 453                            YouBike2.0_敦南山林        文山區
# 454                      YouBike2.0_景美污水抽水站        文山區
# 455                  YouBike2.0_萬和三號公園(北側)        文山區
# 456                            YouBike2.0_景興國中        文山區
# 457                          YouBike2.0_景仁公園_1        文山區
# 458                  YouBike2.0_師大公館校區學二舍        文山區
# 459                            YouBike2.0_景行公園        文山區
# 460                            YouBike2.0_萬興國小        文山區
# 461                    YouBike2.0_辛亥路四段77巷口        文山區
# 462                        YouBike2.0_景興路42巷口        文山區
# 463                      YouBike2.0_木柵路三段48巷        文山區
# 464                     YouBike2.0_木柵路二段109巷        文山區
# 465                            YouBike2.0_試院公園        文山區
# 466                            YouBike2.0_樟樹公園        文山區
# 467                        YouBike2.0_萬美萬安街口        文山區
# 468               YouBike2.0_興隆路二段203巷(敦南)        文山區
# 469                        YouBike2.0_新光秀明路口        文山區
# 470                       YouBike2.0_光輝路134巷口        文山區
# 471                            YouBike2.0_光輝公園        文山區
# 472                            YouBike2.0_木新公園        文山區
# 473                YouBike2.0_興隆路二段275巷1弄口        文山區
# 474                        YouBike2.0_中國科技大學        文山區
# 475                           YouBike2.0_樟新街8巷        文山區
# 476                        YouBike2.0_仙岩路22巷口        文山區
# 477                        YouBike2.0_木柵萬芳路口        文山區
# 478                          YouBike2.0_福興路78巷        文山區
# 479                        YouBike2.0_辛亥木柵路口        文山區
# 480                            YouBike2.0_興泰公園        文山區
# 481                YouBike2.0_興岩社會福利綜合大樓        文山區
# 482                 YouBike2.0_興隆路二段22巷9弄口        文山區
# 483                   YouBike2.0_木新路三段155巷口        文山區
# 484                       YouBike2.0_景興路102巷口        文山區
# 485                         YouBike2.0_景福街223巷        文山區
# 486                          YouBike2.0_達賢圖書館        文山區
# 487                    YouBike2.0_捷運木柵站(西側)        文山區
# 488                    YouBike2.0_世新大學(試院路)        文山區
# 489                    YouBike2.0_興隆社會住宅D1區        文山區
# 490                            YouBike2.0_名門社區        文山區
# 491                        YouBike2.0_政大國際會館        文山區
# 492                        YouBike2.0_萬芳出租國宅        文山區
# 493                            YouBike2.0_景美國小        文山區
# 494                       YouBike2.0_景文街142巷口        文山區
# 495                         YouBike2.0_保儀路142巷        文山區
# 496                    YouBike2.0_臺北自來水事業處        中正區
# 497                  YouBike2.0_汀州思源街口東南側        中正區
# 498                 YouBike2.0_捷運公館站(1號出口)        中正區
# 499                 YouBike2.0_捷運公館站(4號出口)        中正區
# 500                 YouBike2.0_捷運古亭站(9號出口)        中正區
# 501                 YouBike2.0_捷運古亭站(2號出口)        中正區
# 502             YouBike2.0_捷運臺電大樓站(1號出口)        中正區
# 503                    YouBike2.0_客家文化主題公園        中正區
# 504                            YouBike2.0_河堤國小        中正區
# 505                              YouBike2.0_紀州庵        中正區
# 506             YouBike2.0_捷運臺電大樓站(5號出口)        中正區
# 507             YouBike2.0_捷運臺電大樓站(4號出口)        中正區
# 508                  YouBike2.0_羅斯福三段金門街口        中正區
# 509                            YouBike2.0_牯嶺公園        中正區
# 510                 YouBike2.0_捷運古亭站(8號出口)        中正區
# 511                 YouBike2.0_捷運古亭站(7號出口)        中正區
# 512                            YouBike2.0_南昌公園        中正區
# 513                        YouBike2.0_和平重慶路口        中正區
# 514                      YouBike2.0_孫立人將軍官邸        中正區
# 515                   YouBike2.0_羅斯福路二段6巷口        中正區
# 516                      YouBike2.0_金華杭州南路口        中正區
# 517           YouBike2.0_捷運中正紀念堂站(3號出口)        中正區
# 518           YouBike2.0_捷運中正紀念堂站(4號出口)        中正區
# 519                            YouBike2.0_螢橋國小        中正區
# 520                      YouBike2.0_古亭智慧圖書館        中正區
# 521                            YouBike2.0_永昌公園        中正區
# 522                   YouBike2.0_中華路二段409巷口        中正區
# 523              YouBike2.0_南機場夜市(中華路二段)        中正區
# 524                  YouBike2.0_南海和平路口西南側        中正區
# 525                        YouBike2.0_莒光和平路口        中正區
# 526                      YouBike2.0_水源路11-1號旁        中正區
# 527                            YouBike2.0_南門國中        中正區
# 528               YouBike2.0_捷運小南門站(2號出口)        中正區
# 529                            YouBike2.0_介壽公園        中正區
# 530                        YouBike2.0_中華貴陽街口        中正區
# 531                        YouBike2.0_華山文創園區        中正區
# 532               YouBike2.0_捷運善導寺站(1號出口)        中正區
# 533                        YouBike2.0_濟南紹興路口        中正區
# 534                        YouBike2.0_林森仁愛路口        中正區
# 535                        YouBike2.0_中正運動中心        中正區
# 536                        YouBike2.0_信義杭州路口        中正區
# 537               YouBike2.0_捷運善導寺站(3號出口)        中正區
# 538               YouBike2.0_捷運小南門站(1號出口)        中正區
# 539                     YouBike2.0_延平南路133巷口        中正區
# 540                 YouBike2.0_捷運西門站(2號出口)        中正區
# 541                        YouBike2.0_寶慶博愛路口        中正區
# 542                              YouBike2.0_法務部        中正區
# 543              YouBike2.0_臺北市立大學(博愛校區)        中正區
# 544                          YouBike2.0_國家圖書館        中正區
# 545                        YouBike2.0_市民金山路口        中正區
# 546                    YouBike2.0_聯合醫院和平院區        中正區
# 547                              YouBike2.0_中山堂        中正區
# 548                        YouBike2.0_中華漢口街口        中正區
# 549                    YouBike2.0_中華路一段21巷口        中正區
# 550             YouBike2.0_捷運臺大醫院站(4號出口)        中正區
# 551                        YouBike2.0_寶藏巖觀音亭        中正區
# 552                        YouBike2.0_師大水源路口        中正區
# 553                        YouBike2.0_中山徐州路口        中正區
# 554                        YouBike2.0_信義連雲街口        中正區
# 555                          YouBike2.0_臺北轉運站        中正區
# 556                        YouBike2.0_莒光大埔街口        中正區
# 557             YouBike2.0_捷運忠孝新生站(2號出口)        中正區
# 558                            YouBike2.0_光華商場        中正區
# 559                        YouBike2.0_中山青島路口        中正區
# 560           YouBike2.0_捷運中正紀念堂站(5號出口)        中正區
# 561                    YouBike2.0_北平東杭州北路口        中正區
# 562                YouBike2.0_王貫英先生紀念圖書館        中正區
# 563                        YouBike2.0_金山信義路口        中正區
# 564                        YouBike2.0_林森徐州路口        中正區
# 565                        YouBike2.0_徐州杭州路口        中正區
# 566           YouBike2.0_捷運中正紀念堂站(6號出口)        中正區
# 567                YouBike2.0_捷運臺北車站(M2出口)        中正區
# 568          YouBike2.0_臺北市國父史蹟館(逸仙公園)        中正區
# 569                 YouBike2.0_捷運西門站(5號出口)        中正區
# 570                            YouBike2.0_弘道國中        中正區
# 571              YouBike2.0_臺北市第一女子高級中學        中正區
# 572                    YouBike2.0_台北市替代役中心        中正區
# 573                        YouBike2.0_紹興徐州路口        中正區
# 574                    YouBike2.0_羅斯福寧波東街口        中正區
# 575                          YouBike2.0_自來水園區        中正區
# 576                        YouBike2.0_仁愛林森路口        中正區
# 577                 YouBike2.0_捷運西門站(3號出口)        中正區
# 578                        YouBike2.0_仁愛金山路口        中正區
# 579                 YouBike2.0_杭州南路一段101巷口        中正區
# 580                        YouBike2.0_仁愛杭州路口        中正區
# 581                      YouBike2.0_龍興里活動中心        中正區
# 582                              YouBike2.0_植物園        中正區
# 583                          YouBike2.0_郵政博物館        中正區
# 584                        YouBike2.0_林森北平路口        中正區
# 585                        YouBike2.0_北平紹興路口        中正區
# 586                        YouBike2.0_天津北平路口        中正區
# 587             YouBike2.0_捷運忠孝新生站(1號出口)        中正區
# 588             YouBike2.0_捷運忠孝新生站(5號出口)        中正區
# 589             YouBike2.0_捷運臺大醫院站(1號出口)        中正區
# 590                    YouBike2.0_臺大醫院兒童醫院        中正區
# 591                YouBike2.0_林森濟南路口(東北側)        中正區
# 592                  YouBike2.0_仁愛紹興街口(南側)        中正區
# 593                        YouBike2.0_中華南海路口        中正區
# 594                      YouBike2.0_立法院台北會館        中正區
# 595   YouBike2.0_捷運善導寺站(3號出口)(忠孝東路側)        中正區
# 596                          YouBike2.0_國家音樂廳        中正區
# 597                    YouBike2.0_忠孝西重慶南路口        中正區
# 598                     YouBike2.0_濟南路二段8巷口        中正區
# 599                YouBike2.0_仁愛金山路口(東南側)        中正區
# 600                        YouBike2.0_臺灣文學基地        中正區
# 601                      YouBike2.0_重慶南詔安街口        中正區
# 602                            YouBike2.0_文光公園        中正區
# 603           YouBike2.0_捷運中正紀念堂站(2號出口)        中正區
# 604                        YouBike2.0_螢圃里小公園        中正區
# 605                            YouBike2.0_螢橋公園        中正區
# 606                      YouBike2.0_泉州寧波西街口        中正區
# 607                  YouBike2.0_和平西路二段98巷口        中正區
# 608                YouBike2.0_仁愛新生路口(西南側)        中正區
# 609                            YouBike2.0_幸安市場        中正區
# 610                            YouBike2.0_龍口市場        中正區
# 611               YouBike2.0_捷運善導寺站(5號出口)        中正區
# 612                        YouBike2.0_青島杭州路口        中正區
# 613                        YouBike2.0_詔安街37巷口        中正區
# 614                       YouBike2.0_南海路112巷口        中正區
# 615                          YouBike2.0_牯嶺街95巷        中正區
# 616                  YouBike2.0_仁愛紹興路口(北側)        中正區
# 617                        YouBike2.0_貴陽博愛路口        中正區
# 618                YouBike2.0_國立臺灣博物館南門館        中正區
# 619                   YouBike2.0_汀州路一段106巷口        中正區
# 620                 YouBike2.0_羅斯福路四段108巷口        中正區
# 621                        YouBike2.0_公館水岸廣場        中正區
# 622                        YouBike2.0_通北街65巷口        中山區
# 623                          YouBike2.0_圓山風景區        中山區
# 624                    YouBike2.0_樂群二堤頂大道口        中山區
# 625                            YouBike2.0_劍潭社區        中山區
# 626                            YouBike2.0_培英公園        中山區
# 627                      YouBike2.0_樂群二明水路口        中山區
# 628                        YouBike2.0_北安大直街口        中山區
# 629               YouBike2.0_捷運劍南路站(2號出口)        中山區
# 630                    YouBike2.0_樂群二敬業三路口        中山區
# 631                    YouBike2.0_樂群二敬業四路口        中山區
# 632                 YouBike2.0_捷運大直站(3號出口)        中山區
# 633                        YouBike2.0_復興市民路口        中山區
# 634                        YouBike2.0_南京遼寧街口        中山區
# 635                        YouBike2.0_伊通長安路口        中山區
# 636                        YouBike2.0_新生長安路口        中山區
# 637                        YouBike2.0_市民林森路口        中山區
# 638                        YouBike2.0_南京新生路口        中山區
# 639                            YouBike2.0_一江公園        中山區
# 640                            YouBike2.0_松江公園        中山區
# 641                        YouBike2.0_新生長春路口        中山區
# 642                    YouBike2.0_第二果菜批發市場        中山區
# 643                        YouBike2.0_民生建國路口        中山區
# 644                            YouBike2.0_興安華城        中山區
# 645                      YouBike2.0_捷運中山國中站        中山區
# 646                        YouBike2.0_龍江錦州街口        中山區
# 647                        YouBike2.0_建國長春路口        中山區
# 648                        YouBike2.0_南京建國路口        中山區
# 649             YouBike2.0_捷運松江南京站(7號出口)        中山區
# 650                            YouBike2.0_朱崙商場        中山區
# 651                            YouBike2.0_中吉公園        中山區
# 652                            YouBike2.0_華山公園        中山區
# 653                    YouBike2.0_建國北路一段17巷        中山區
# 654                            YouBike2.0_江寧公園        中山區
# 655                        YouBike2.0_民權龍江路口        中山區
# 656             YouBike2.0_捷運中山國小站(2號出口)        中山區
# 657               YouBike2.0_捷運行天宮站(3號出口)        中山區
# 658                        YouBike2.0_林森農安街口        中山區
# 659             YouBike2.0_捷運中山國小站(4號出口)        中山區
# 660                        YouBike2.0_農安雙城街口        中山區
# 661                        YouBike2.0_新生德惠街口        中山區
# 662                        YouBike2.0_民族林森路口        中山區
# 663                      YouBike2.0_臺北市立美術館        中山區
# 664                        YouBike2.0_中山民族路口        中山區
# 665     YouBike2.0_新生高架停車場(林森北路107巷口)        中山區
# 666                YouBike2.0_南京林森路口(東南側)        中山區
# 667                            YouBike2.0_仁德公園        中山區
# 668                            YouBike2.0_中原公園        中山區
# 669                            YouBike2.0_下埤公園        中山區
# 670                            YouBike2.0_五常國中        中山區
# 671                            YouBike2.0_榮星花園        中山區
# 672                        YouBike2.0_民權建國路口        中山區
# 673                       YouBike2.0_松江路431巷口        中山區
# 674                            YouBike2.0_新喜公園        中山區
# 675                       YouBike2.0_吉林路407巷口        中山區
# 676                        YouBike2.0_民族松江路口        中山區
# 677                          YouBike2.0_林安泰古厝        中山區
# 678                        YouBike2.0_中山公民會館        中山區
# 679                        YouBike2.0_渭水八德路口        中山區
# 680                 YouBike2.0_捷運中山站(2號出口)        中山區
# 681                            YouBike2.0_撫順公園        中山區
# 682                            YouBike2.0_新生公園        中山區
# 683               YouBike2.0_捷運行天宮站(1號出口)        中山區
# 684                        YouBike2.0_林森長春路口        中山區
# 685                        YouBike2.0_建國農安街口        中山區
# 686                        YouBike2.0_松江路77巷口        中山區
# 687                        YouBike2.0_建國長安路口        中山區
# 688                        YouBike2.0_市民新生路口        中山區
# 689                        YouBike2.0_民權吉林路口        中山區
# 690                        YouBike2.0_中山農安街口        中山區
# 691                        YouBike2.0_捷運行政大樓        中山區
# 692               YouBike2.0_中吉公園(松江路188巷)        中山區
# 693                       YouBike2.0_吉林路123巷口        中山區
# 694                        YouBike2.0_中原民生路口        中山區
# 695              YouBike2.0_國立臺北大學(臺北校區)        中山區
# 696                        YouBike2.0_錦州吉林路口        中山區
# 697                  YouBike2.0_中山北路二段59巷口        中山區
# 698          YouBike2.0_永盛公園(民生東路一段23巷)        中山區
# 699                        YouBike2.0_新生錦州街口        中山區
# 700                       YouBike2.0_濱江街199巷口        中山區
# 701                        YouBike2.0_大佳社區公園        中山區
# 702                        YouBike2.0_濱江果菜市場        中山區
# 703                        YouBike2.0_興安合江路口        中山區
# 704                 YouBike2.0_復興北路514巷口東側        中山區
# 705                            YouBike2.0_台泥大樓        中山區
# 706                        YouBike2.0_植福樂群路口        中山區
# 707                            YouBike2.0_新興公園        中山區
# 708                        YouBike2.0_南京伊通街口        中山區
# 709                        YouBike2.0_南京龍江路口        中山區
# 710                YouBike2.0_撫順街41巷(崇德宮前)        中山區
# 711              YouBike2.0_臺北市立圖書館大直分館        中山區
# 712                 YouBike2.0_捷運大直站(1號出口)        中山區
# 713             YouBike2.0_捷運松江南京站(4號出口)        中山區
# 714                           YouBike2.0_中429公園        中山區
# 715                       YouBike2.0_長春路137巷口        中山區
# 716                        YouBike2.0_松江民生路口        中山區
# 717                       YouBike2.0_松江路132巷口        中山區
# 718                        YouBike2.0_長春吉林路口        中山區
# 719                        YouBike2.0_長春一江街口        中山區
# 720             YouBike2.0_捷運松江南京站(8號出口)        中山區
# 721                        YouBike2.0_南京一江街口        中山區
# 722                        YouBike2.0_松江長春路口        中山區
# 723                    YouBike2.0_經國七海文化園區        中山區
# 724                        YouBike2.0_民族玉門街口        中山區
# 725                        YouBike2.0_新生農安街口        中山區
# 726            YouBike2.0_稻江高級護理家事職業學校        中山區
# 727               YouBike2.0_捷運大直站(3號出口)_1        中山區
# 728                    YouBike2.0_樂群二明水路口_1        中山區
# 729                  YouBike2.0_民權吉林路口(南側)        中山區
# 730                        YouBike2.0_長春龍江路口        中山區
# 731                        YouBike2.0_民權新生路口        中山區
# 732                  YouBike2.0_建國長春路口(北側)        中山區
# 733                        YouBike2.0_中山行政中心        中山區
# 734                    YouBike2.0_臺北市立美術館_1        中山區
# 735                          YouBike2.0_劍潭社區_1        中山區
# 736                      YouBike2.0_濱江國小游泳池        中山區
# 737                            YouBike2.0_林森公園        中山區
# 738                           YouBike2.0_中428公園        中山區
# 739                            YouBike2.0_復華公園        中山區
# 740                YouBike2.0_新生民族路口(西南側)        中山區
# 741             YouBike2.0_捷運南京復興站(1號出口)        中山區
# 742                      YouBike2.0_八德市場(北側)        中山區
# 743                        YouBike2.0_龍江朱崙街口        中山區
# 744                          YouBike2.0_大直街94巷        中山區
# 745             YouBike2.0_捷運南京復興站(8號出口)        中山區
# 746                  YouBike2.0_民權建國路口(南側)        中山區
# 747                        YouBike2.0_林森德惠街口        中山區
# 748                YouBike2.0_新生濱江街口(東南側)        中山區
# 749                  YouBike2.0_新生北路一段62巷口        中山區
# 750                YouBike2.0_新生長春路口(東北側)        中山區
# 751               YouBike2.0_捷運劍南路站(1號出口)        中山區
# 752            YouBike2.0_敬業三樂群三路口(西北側)        中山區
# 753                    YouBike2.0_長春路258巷2弄口        中山區
# 754                  YouBike2.0_長寧大廈社區(南側)        中山區
# 755                        YouBike2.0_建國五常街口        中山區
# 756                  YouBike2.0_中山北路二段62巷口        中山區
# 757                        YouBike2.0_市民安東街口        中山區
# 758                   YouBike2.0_市民大道二段5巷口        中山區
# 759                 YouBike2.0_捷運中山站(3號出口)        中山區
# 760           YouBike2.0_建國北路高架橋下停車場G區        中山區
# 761                            YouBike2.0_朱崙公園        中山區
# 762                      YouBike2.0_朱崙復興北路口        中山區
# 763               YouBike2.0_捷運行天宮站(4號出口)        中山區
# 764                  YouBike2.0_建國北路三段86巷口        中山區
# 765                            YouBike2.0_正守公園        中山區
# 766                        YouBike2.0_四平松江路口        中山區
# 767                        YouBike2.0_北安通北街口        中山區
# 768            YouBike2.0_民權東復興北路口(西北側)        中山區
# 769                    YouBike2.0_臺北市立大同高中        中山區
# 770                          YouBike2.0_中崙加油站        中山區
# 771              YouBike2.0_北安明水路口(自強隧道)        中山區
# 772          YouBike2.0_中正國小(南京東路三段48巷)        中山區
# 773                        YouBike2.0_臺北時代廣場        中山區
# 774                YouBike2.0_吉林農安街口(西北側)        中山區
# 775                            YouBike2.0_濱江國中        中山區
# 776                          YouBike2.0_環山抽水站        中山區
# 777                YouBike2.0_民權中山路口(東北側)        中山區
# 778                YouBike2.0_復興五常街口(西南側)        中山區
# 779                        YouBike2.0_松江長安路口        中山區
# 780                            YouBike2.0_長安國小        中山區
# 781                            YouBike2.0_中山市場        中山區
# 782                 YouBike2.0_捷運雙連站(1號出口)        中山區
# 783                YouBike2.0_吉林南京路口(西北側)        中山區
# 784                         YouBike2.0_龍江路345巷        中山區
# 785               YouBike2.0_捷運劍南路站(3號出口)        中山區
# 786              YouBike2.0_一江南京東路口(西南側)        中山區
# 787                    YouBike2.0_大直抽水站公車站        中山區
# 788                  YouBike2.0_民權東路三段39巷口        中山區
# 789                    YouBike2.0_臺北市立中山女高        中山區
# 790                            YouBike2.0_朱昌公園        中山區
# 791                      YouBike2.0_林森公園東北側        中山區
# 792                      YouBike2.0_康樂公園西北側        中山區
# 793                      YouBike2.0_中山北德惠街口        中山區
# 794                            YouBike2.0_晴光公園        中山區
# 795                        YouBike2.0_松江路25巷口        中山區
# 796                      YouBike2.0_民生東合江街口        中山區
# 797                        YouBike2.0_飛航服務總臺        中山區
# 798                YouBike2.0_內湖堤頂大道(西南側)        中山區
# 799                   YouBike2.0_文湖街21巷118弄口        內湖區
# 800                      YouBike2.0_北勢湖環保公園        內湖區
# 801                        YouBike2.0_洲子一號公園        內湖區
# 802                            YouBike2.0_西康公園        內湖區
# 803                            YouBike2.0_文湖國小        內湖區
# 804                  YouBike2.0_文湖街81巷10號西側        內湖區
# 805                    YouBike2.0_德明財經科技大學        內湖區
# 806                            YouBike2.0_麗山國小        內湖區
# 807                            YouBike2.0_麗山高中        內湖區
# 808                        YouBike2.0_港華五號公園        內湖區
# 809                            YouBike2.0_大湖國小        內湖區
# 810                        YouBike2.0_安湖三號公園        內湖區
# 811                     YouBike2.0_東湖路113巷95弄        內湖區
# 812                    YouBike2.0_瑞光計程車服務站        內湖區
# 813        YouBike2.0_文德三號公園(江南街71巷16弄)        內湖區
# 814             YouBike2.0_捷運大湖公園站(2號出口)        內湖區
# 815                        YouBike2.0_康寧星雲街口        內湖區
# 816                          YouBike2.0_星雲街47號        內湖區
# 817                 YouBike2.0_捷運西湖站(1號出口)        內湖區
# 818                 YouBike2.0_捷運西湖站(2號出口)        內湖區
# 819                        YouBike2.0_洲子二號公園        內湖區
# 820                            YouBike2.0_港都公園        內湖區
# ...
# 971         20        1
# 972         10        1
# 973         28        1
# 974         17        1
# 975          7        1
# 976         21        1
# 977         17        1
# 978         11        1
# 979         18        1
# 980         16        1
# 981         12        1
# 982         16        1
# 983         22        1
# 984          5        1
# 985         28        1
# 986         23        1
# 987         21        1
# 988         21        1
# 989         29        1
# 990         24        1
# 991          3        1
# 992         13        1
# 993         60        1
# 994         19        1
# 995         26        1
# 996         12        1
# 997         41        1
# 998         14        1
# 999         29        1
# 1000         2        1
# 1001        45        1
# 1002        36        1
# 1003        22        1
# 1004        30        1
# 1005        24        1
# 1006        36        1
# 1007        17        1
# 1008        52        1
# 1009        17        1
# 1010        17        1
# 1011         9        1
# 1012        15        1
# 1013        26        1
# 1014        48        1
# 1015        27        1
# 1016        41        1
# 1017        10        1
# 1018        35        1
# 1019        13        1
# 1020        25        1
# 1021        23        1
# 1022        16        1
# 1023        14        1
# 1024         8        1
# 1025        16        1
# 1026        38        1
# 1027         5        1
# 1028        30        1
# 1029        17        1
# 1030        27        1
# 1031        17        1
# 1032        16        1
# 1033        38        1
# 1034        29        1
# 1035        22        1
# 1036        22        1
# 1037        20        1
# 1038        13        1
# 1039        27        1
# 1040        14        1
# 1041        10        1
# 1042        12        1
# 1043         6        1
# 1044        25        1
# 1045        24        0
# 1046        20        1
# 1047        10        1
# 1048        33        1
# 1049        15        1
# 1050        23        1
# 1051        16        1
# 1052         5        1
# 1053        16        1
# 1054        21        1
# 1055        27        1
# 1056        16        1
# 1057         5        1
# 1058        22        1
# 1059         6        1
# 1060        10        1
# 1061         9        1
# 1062        10        1
# 1063        18        1
# 1064        27        1
# 1065        10        1
# 1066        13        1
# 1067         8        1
# 1068         8        1
# 1069        22        1
# 1070        23        1
# 1071        14        1
# 1072         9        1
# 1073         9        1
# 1074         2        1
# 1075        14        1
# 1076        19        1
# 1077         9        1
# 1078        32        1
# 1079        13        1
# 1080         3        1
# 1081        13        1
# 1082        12        1
# 1083        24        1
# 1084        25        1
# 1085        17        1
# 1086        28        1
# 1087        21        1
# 1088        61        1
# 1089         7        1
# 1090        37        1
# 1091        17        1
# 1092        13        1
# 1093        13        1
# 1094        30        1
# 1095        13        1
# 1096        27        1
# 1097        36        1
# 1098        14        1
# 1099         9        1
# 1100        38        1
# 1101         2        1
# 1102         9        1
# 1103        12        1
# 1104        43        1
# 1105        31        1
# 1106        50        1
# 1107        31        1
# 1108        25        1
# 1109        12        1
# 1110        12        1
# 1111        41        1
# 1112        15        1
# 1113        20        1
# 1114        23        1
# 1115        26        1
# 1116        16        1
# 1117        10        1
# 1118        24        1
# 1119        11        1
# 1120        14        1
# 1121        21        1
# 1122        41        1
# 1123        26        1
# 1124        36        1
# 1125        11        1
# 1126        10        1
# 1127         2        1
# 1128        30        1
# 1129        31        1
# 1130        17        1
# 1131         9        1
# 1132         0        1
# 1133        10        1
# 1134        21        1
# 1135        15        1
# 1136        20        1
# 1137        15        1
# 1138         9        1
# 1139        15        1
# 1140         5        1
# 1141         5        1
# 1142        10        1
# 1143        29        1
# 1144        29        1
# 1145        43        1
# 1146        10        1
# 1147         8        1
# 1148        50        1
# 1149        25        1
# 1150        29        1
# 1151        12        1
# 1152        16        1
# 1153         8        1
# 1154        24        1
# 1155        14        1
# 1156         1        1
# 1157        12        1
# 1158        23        1
# 1159        20        1
# 1160        26        1
# 1161        14        1
# 1162         6        1
# 1163        12        1
# 1164         5        1
# 1165        10        1
# 1166        24        1
# 1167         8        1
# 1168        23        1
# 1169        15        0
# 1170        14        1
# 1171        22        1
# 1172        22        1
# 1173        33        1
# 1174        11        1
# 1175         5        1
# 1176        44        1
# 1177        41        1
# 1178        27        1
# 1179        41        1
# 1180        11        1
# 1181        26        1
# 1182        42        1
# 1183        22        1
# 1184        29        1
# 1185        14        1
# 1186        29        1
# 1187        46        1
# 1188        38        1
# 1189        29        1
# 1190        32        1
# 1191        24        1
# 1192        10        1
# 1193        37        0
# 1194        32        1
# 1195        24        1
# 1196         8        1
# 1197        47        1
# 1198        19        1
# 1199         5        1
# 1200         8        1
# 1201        17        1
# 1202        18        1
# 1203        17        1
# 1204        18        1
# 1205        20        1
# 1206        18        1
# 1207        23        1
# 1208        10        1
# 1209        21        1
# 1210        20        1
# 1211        23        1
# 1212        22        1
# 1213        24        1
# 1214        18        1
# 1215        25        1
# 1216        11        1
# 1217        21        1
# 1218        13        1
# 1219        30        1
# 1220         9        1
# 1221        17        1
# 1222        22        1
# 1223        16        1
# 1224        20        1
# 1225         4        1
# 1226        16        1
# 1227        18        1
# 1228         9        1
# 1229        27        1
# 1230        12        1
# 1231        18        1
# 1232        13        1
# 1233        17        1
# 1234        45        1
# 1235         9        1
# 1236        19        1
# 1237         9        1
# 1238        13        1
# 1239         3        1
# 1240         9        1
# 1241         4        1
# 1242        17        1
# 1243        29        1
# 1244        22        1
# 1245        25        1
# 1246        25        1
# 1247        14        1
# 1248        18        1
# 1249        10        1
# 1250        12        1
# 1251         9        1
# 1252        13        1
# 1253        25        1
# 1254        14        1
# 1255        25        1
# 1256         8        1
# 1257        13        1
# 1258        13        1
# 1259         7        1
# 1260         4        1
# 1261        13        1
# 1262        23        1
# 1263        12        1
# 1264        12        1
# 1265        22        1
# 1266        13        1
# 1267        13        1
# 1268        13        1
# 1269         9        1
# 1270        10        1
# 1271        34        1
# 1272        12        1
# 1273         2        1
# 1274        12        1
# 1275        21        1
# 1276        16        1
# 1277         2        1
# 1278        22        1
# 1279        16        1
# 1280        15        1
# 1281        40        1
# 1282        64        1
# 1283        40        1
# 1284        57        1
# 1285         0        1
# 1286         8        1
# 1287        22        1
# 1288         1        1
# 1289        17        1
# 1290        24        1
# 1291        18        1
# 1292        44        1
# 1293        16        1
# 1294         2        1
# 1295        15        1
# 1296         0        0
# 1297        50        1
# 1298        28        1
# 1299        18        1
# 1300        29        1
# 1301        49        1
# 1302        24        1
# 1303        16        1
# 1304        36        1
# 1305         2        1
# 1306        10        1
# 1307        33        1
# 1308         2        1
# 1309         9        1
# 1310        15        1
# 1311        28        1
# 1312         0        1
# 1313        39        1
# 1314        31        1
# 1315         8        1
# 1316        15        1
# 1317        25        1
# 1318        36        1
# 1319        25        1
# 1320        19        1
# 1321        12        1
# 1322        27        1
# 1323        28        1
# 1324        30        1
# 1325        23        1
# 1326        18        1
# 1327         5        1
# 1328        30        1
# 1329        14        1
# 1330        21        1
# 1331         6        1
# 1332        20        1
# 1333        25        1
# 1334        19        1
# 1335        18        1
# 1336        17        1
# 1337        14        1
# 1338        23        1
# 1339         4        1
# 1340        25        1
# 1341        21        1
# 1342        24        1
# 1343        23        1
# 1344        24        1
# 1345        41        1
# 1346        37        1
# 1347         0        1
# 1348         8        1
# 1349        25        1
# 1350         9        1
# 1351        16        1
# 1352         0        1
# 1353        20        1
# 1354        14        1
# 1355        25        1
# 1356        67        1
# 1357        10        1
# 1358        17        1
# 1359        11        1
# 1360        15        1
# 1361         8        1
# 1362         0        1
# 1363        23        1
# 1364         1        1
# 1365        13        1
# 1366        19        1
# 1367        17        1
# 1368        16        1
# 1369        10        1
# 1370        23        1
# 1371        21        1
# 1372        16        1
# 1373        16        1
# 1374        10        1
# 1375         5        1
# 1376         4        1
# 1377         7        1
# 1378        19        1
# 1379        22        1
# 1380        21        1
# 1381        15        1
# 1382        22        1
# 1383        15        1
# 1384        12        1
# 1385        14        1
# 1386        19        1
# 1387         7        1
# 1388        20        1
# 1389        10        1
# 1390        16        1
# 1391        10        1
# 1392        19        1
# 1393        22        1
# 1394        23        1
# 1395        19        1
# 1396        44        1
# 1397        25        1
# 1398        22        1
# 1399        30        1
# 1400        16        1
# 1401         5        1
# 1402         6        1
# 1403         3        1
# 1404        11        1
# 1405        11        1
# 1406        18        1
# 1407        14        1
# 1408        41        1
# 1409        21        1
# 1410        23        1
# 1411        23        1
# 1412        14        1
# 1413        12        1
# 1414        13        1
# 1415        34        1
# 1416         6        1
# 1417        15        1
# 1418        20        1
# 1419        48        1
# 1420        31        1
# 1421        24        1
# 1422        14        1
# 1423        42        1
# 1424        33        1
# 1425        10        1
# 1426        23        1
# 1427        14        1
# 1428        14        1
# 1429        17        1
# 1430         1        1
# 1431        18        1
# 1432        12        1
# 1433        13        1
# 1434        16        1
# 1435        11        1
# 1436         7        1
# 1437         1        1
# 1438        18        1
# 1439        15        1
# 1440         6        1
# 1441        20        1
# 1442        29        1
# 1443        23        1
# 1444        26        1
# 1445        13        1
# 1446         7        1
# 1447         1        1
# 1448        13        1
# 1449        14        1
# 1450        26        1
# 1451        20        1
# 1452        10        1
# 1453        18        1
# 1454         7        1
# 1455        10        1
# 1456        10        1
# 1457        14        1
# 1458        10        1
# 1459        15        1
# 1460        10        1
# 1461         9        1
# 1462        19        1
# 1463        11        1
# 1464        19        1
# 1465        10        1
# 1466         5        1
# 1467         3        1
# 1468        13        1
# 1469        31        1
# 1470        92        1
# 1471        34        1
# 1472         9        1
# 1473        29        1
# 1474        40        1
# 1475        18        1
# 1476        13        1
# 1477        31        1
# 1478        26        1
# 1479        49        1
# 1480        74        1
# 1481        15        1
# 1482        25        1
# 1483        23        1
# 1484         0        1
# 1485        17        1
# 1486         5        1
# 1487         7        1
# 1488        39        1
# 1489        10        1
# 1490        58        1
# 1491         8        1
# 1492        22        1
# 1493        10        1
# 1494        26        1
# 1495        25        1
# 1496         9        1
# 1497         7        1
# 1498        33        1
# 1499        54        1
# 1500        17        1
# 1501        47        1
# 1502        34        1
# 1503         7        1
# 1504        11        1
# 1505        41        1
# 1506         6        1
# 1507        31        1
# 1508         2        1
# 1509        11        1
# 1510        10        1
# 1511        26        1
# 1512         9        1
# 1513        11        1
# 1514        25        1
# 1515         9        1
# 1516        46        1
# 1517        20        1
# 1518        32        1
# 1519         6        1
# 1520        27        1
# 1521        13        1
# 1522        15        1
# 1523        18        1
# 1524        13        1
# 1525        32        1
# 1526        82        1
# 1527        39        1
#
# YouBike 各區域統計資訊：
# --------------------------------------------------------------------------------
#               站點數  總車位數  可借車總數  平均可借車數  可還車總數  \
# 區域
# 中山區           177      4342        1321          7.46        2975
# 中正區           126      3446        1105          8.77        2141
# 信義區           113      3543        1303         11.53        2167
# 內湖區           184      4134        1220          6.63        2903
# 北投區           102      2813         739          7.25        2017
# 南港區           101      2638         717          7.10        1912
# 士林區           130      3141         872          6.71        2211
# 大同區            67      1845         477          7.12        1332
# 大安區           194      5335        1739          8.96        3550
# 文山區           105      2434         503          4.79        1919
# 松山區            90      2482         679          7.54        1765
# 臺大公館校區      59      2048         547          9.27        1479
# 萬華區            80      2102         744          9.30        1319
#
#               平均可還車數
# 區域
# 中山區               16.81
# 中正區               16.99
# 信義區               19.18
# 內湖區               15.78
# 北投區               19.77
# 南港區               18.93
# 士林區               17.01
# 大同區               19.88
# 大安區               18.30
# 文山區               18.28
# 松山區               19.61
# 臺大公館校區         25.07
# 萬華區               16.49

# %%
import pandas as pd
import requests
from math import radians, sin, cos, sqrt, asin
import json

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

def haversine(lat1, lon1, lat2, lon2):
    """計算兩點間的距離（公里）"""
    R = 6371  # 地球半徑（公里）
    
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    return R * c

def find_nearest_parking(my_lat, my_lon, n=10):
    """找出最近的n個停車場"""
    
    # 下載並讀取停車場資料
    URL = "https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=16E999BB-27E0-4CD9-8397-FD06B62A742F"
    
    try:
        response = requests.get(URL)
        data = response.json()
        
        # 將資料轉換為 DataFrame
        df = pd.DataFrame(data['data'])
        
        # 計算每個停車場與當前位置的距離
        df['距離'] = df.apply(
            lambda row: haversine(
                my_lat, 
                my_lon, 
                float(row['緯度']), 
                float(row['經度'])
            ), 
            axis=1
        )
        
        # 排序並取得最近的n個停車場
        nearest = df.sort_values('距離').head(n)
        
        # 顯示結果
        print(f"\n離座標 ({my_lat}, {my_lon}) 最近的 {n} 個停車場：")
        print("-" * 80)
        
        result = nearest[[
            '停車場名稱', 
            '行政區', 
            '地址', 
            '距離',
            '收費標準',
            '總計車位'
        ]].copy()
        
        # 將距離四捨五入到小數點後2位
        result['距離'] = result['距離'].round(2)
        result['距離'] = result['距離'].astype(str) + ' 公里'
        
        print(result)
        
        # 儲存結果
        result.to_csv('nearest_parking.csv', encoding='utf-8-sig', index=False)
        print("\n結果已儲存至 nearest_parking.csv")
        
    except Exception as e:
        print(f"發生錯誤：{str(e)}")

# 使用範例（台北車站附近）
my_latitude = 25.048055    # 您的緯度
my_longitude = 121.517308  # 您的經度

find_nearest_parking(my_latitude, my_longitude, 10)
# Out:
# 發生錯誤：HTTPSConnectionPool(host='adsapi.stois.nchc.tw', port=443): Max retries exceeded with url: /AutoDrivingParkingAvailability (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1000)')))

# %%
import pandas as pd
import requests
from math import radians, sin, cos, sqrt, asin
import json
import urllib3

# 關閉 SSL 警告
urllib3.disable_warnings()

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

def find_nearest_parking(my_lat, my_lon, n=10):
    """找出最近的n個停車場"""
    
    # 下載並讀取停車場資料
    URL = "https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=16E999BB-27E0-4CD9-8397-FD06B62A742F"
    
    try:
        # 設定 verify=False 來忽略 SSL 驗證
        response = requests.get(URL, verify=False)
        if response.status_code != 200:
            print(f"錯誤: HTTP 狀態碼 {response.status_code}")
            return
            
        data = response.json()
        
        # 其餘程式碼保持不變
           # 將資料轉換為 DataFrame
        df = pd.DataFrame(data['data'])
        
        # 計算每個停車場與當前位置的距離
        df['距離'] = df.apply(
            lambda row: haversine(
                my_lat, 
                my_lon, 
                float(row['緯度']), 
                float(row['經度'])
            ), 
            axis=1
        )
        
        # 排序並取得最近的n個停車場
        nearest = df.sort_values('距離').head(n)
        
        # 顯示結果
        print(f"\n離座標 ({my_lat}, {my_lon}) 最近的 {n} 個停車場：")
        print("-" * 80)
        
        result = nearest[[
            '停車場名稱', 
            '行政區', 
            '地址', 
            '距離',
            '收費標準',
            '總計車位'
        ]].copy()
        
        # 將距離四捨五入到小數點後2位
        result['距離'] = result['距離'].round(2)
        result['距離'] = result['距離'].astype(str) + ' 公里'
        
        print(result)
        
        # 儲存結果
        result.to_csv('nearest_parking.csv', encoding='utf-8-sig', index=False)
        print("\n結果已儲存至 nearest_parking.csv")
        
    except Exception as e:
        print(f"發生錯誤：{str(e)}")
        print("詳細錯誤資訊：")
        import traceback
        print(traceback.format_exc())

# 使用範例（台北車站附近）
my_latitude = 25.048055    # 您的緯度
my_longitude = 121.517308  # 您的經度

find_nearest_parking(my_latitude, my_longitude, 10)
# Out:
# 發生錯誤：list indices must be integers or slices, not str
# 詳細錯誤資訊：
# Traceback (most recent call last):
#   File "C:\Users\bigpa\AppData\Local\Temp\ipykernel_18792\3281816706.py", line 33, in find_nearest_parking
#     df = pd.DataFrame(data['data'])
#                       ~~~~^^^^^^^^
# TypeError: list indices must be integers or slices, not str

# %%
import pandas as pd
import requests
from math import radians, sin, cos, sqrt, asin
import json
import urllib3

# 關閉 SSL 警告
urllib3.disable_warnings()

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

def haversine(lat1, lon1, lat2, lon2):
    """計算兩點間的距離（公里）"""
    R = 6371  # 地球半徑（公里）
    
    # 將經緯度轉換為弧度
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    
    # haversine 公式
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    return R * c

def find_nearest_parking(my_lat, my_lon, n=10):
    """找出最近的n個停車場"""
    
    # 下載並讀取停車場資料
    URL = "https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=16E999BB-27E0-4CD9-8397-FD06B62A742F"
    
    try:
        # 設定 verify=False 來忽略 SSL 驗證
        response = requests.get(URL, verify=False)
        if response.status_code != 200:
            print(f"錯誤: HTTP 狀態碼 {response.status_code}")
            return
            
        data = response.json()
        
        # 將資料轉換為 DataFrame
        df = pd.DataFrame(data['data'])
        
        # 計算每個停車場與當前位置的距離
        df['距離'] = df.apply(
            lambda row: haversine(
                my_lat, 
                my_lon, 
                float(row['緯度']), 
                float(row['經度'])
            ), 
            axis=1
        )
        
        # 排序並取得最近的n個停車場
        nearest = df.sort_values('距離').head(n)
        
        # 顯示結果
        print(f"\n離座標 ({my_lat}, {my_lon}) 最近的 {n} 個停車場：")
        print("-" * 80)
        
        result = nearest[[
            '停車場名稱', 
            '行政區', 
            '地址', 
            '距離',
            '收費標準',
            '總計車位'
        ]].copy()
        
        # 將距離四捨五入到小數點後2位
        result['距離'] = result['距離'].round(2)
        result['距離'] = result['距離'].astype(str) + ' 公里'
        
        print(result.to_string(index=False))
        
        # 儲存結果
        result.to_csv('nearest_parking.csv', encoding='utf-8-sig', index=False)
        print("\n結果已儲存至 nearest_parking.csv")
        
    except Exception as e:
        print(f"發生錯誤：{str(e)}")
        print("詳細錯誤資訊：")
        import traceback
        print(traceback.format_exc())

# 使用範例（台北車站附近）
if __name__ == "__main__":
    my_latitude = 25.048055    # 您的緯度
    my_longitude = 121.517308  # 您的經度
    
    find_nearest_parking(my_latitude, my_longitude, 10)
# Out:
# 發生錯誤：list indices must be integers or slices, not str
# 詳細錯誤資訊：
# Traceback (most recent call last):
#   File "C:\Users\bigpa\AppData\Local\Temp\ipykernel_18792\3803043982.py", line 47, in find_nearest_parking
#     df = pd.DataFrame(data['data'])
#                       ~~~~^^^^^^^^
# TypeError: list indices must be integers or slices, not str

# %%
import pandas as pd
import requests
from math import radians, sin, cos, sqrt, asin
import json
import urllib3

# 關閉 SSL 警告
urllib3.disable_warnings()

# 設定 Pandas 顯示選項
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

def haversine(lat1, lon1, lat2, lon2):
    """計算兩點間的距離（公里）"""
    R = 6371  # 地球半徑（公里）
    
    # 將經緯度轉換為弧度
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    
    # haversine 公式
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    
    return R * c

def find_nearest_parking(my_lat, my_lon, n=10):
    """找出最近的n個停車場"""
    
    # 下載並讀取停車場資料
    URL = "https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=16E999BB-27E0-4CD9-8397-FD06B62A742F"
    
    try:
        # 設定 verify=False 來忽略 SSL 驗證
        response = requests.get(URL, verify=False)
        if response.status_code != 200:
            print(f"錯誤: HTTP 狀態碼 {response.status_code}")
            return
            
        # 直接將 JSON 轉換為 DataFrame，因為資料是列表格式
        df = pd.DataFrame(response.json())
        
        # 計算每個停車場與當前位置的距離
        df['距離'] = df.apply(
            lambda row: haversine(
                my_lat, 
                my_lon, 
                float(row['緯度']), 
                float(row['經度'])
            ), 
            axis=1
        )
        
        # 排序並取得最近的n個停車場
        nearest = df.sort_values('距離').head(n)
        
        # 顯示結果
        print(f"\n離座標 ({my_lat}, {my_lon}) 最近的 {n} 個停車場：")
        print("-" * 80)
        
        result = nearest[[
            '停車場名稱', 
            '行政區', 
            '地址', 
            '距離',
            '收費標準',
            '總計車位'
        ]].copy()
        
        # 將距離四捨五入到小數點後2位
        result['距離'] = result['距離'].round(2)
        result['距離'] = result['距離'].astype(str) + ' 公里'
        
        print(result.to_string(index=False))
        
        # 儲存結果
        result.to_csv('nearest_parking.csv', encoding='utf-8-sig', index=False)
        print("\n結果已儲存至 nearest_parking.csv")
        
    except Exception as e:
        print(f"發生錯誤：{str(e)}")
        print("詳細錯誤資訊：")
        import traceback
        print(traceback.format_exc())

# 使用範例（台北車站附近）
my_latitude = 25.048055    # 您的緯度
my_longitude = 121.517308  # 您的經度

find_nearest_parking(my_latitude, my_longitude, 10)
# Out:
# 發生錯誤：'緯度'
# 詳細錯誤資訊：
# Traceback (most recent call last):
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\indexes\base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\\_libs\\hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\\_libs\\hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: '緯度'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\bigpa\AppData\Local\Temp\ipykernel_18792\3697933888.py", line 48, in find_nearest_parking
#     df['距離'] = df.apply(
#                  ^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\frame.py", line 10374, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\apply.py", line 916, in apply
#     return self.apply_standard()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\apply.py", line 1063, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\apply.py", line 1081, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\bigpa\AppData\Local\Temp\ipykernel_18792\3697933888.py", line 52, in <lambda>
#     float(row['緯度']),
#          ~~~^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\series.py", line 1121, in __getitem__
#     return self._get_value(key)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\series.py", line 1237, in _get_value
#     loc = self.index.get_loc(label)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\bigpa\anaconda\Lib\site-packages\pandas\core\indexes\base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: '緯度'
